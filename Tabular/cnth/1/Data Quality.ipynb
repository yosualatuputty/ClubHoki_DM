# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns

df_raw = pd.read_csv("../data/train.csv")
df_dq = df_raw.copy()
df_dq
# Out:
#           id                    timestamp     remote_addr remote_user  \
# 0          0  Aug 29, 2023 @ 17:00:03.058   114.4.220.184           -
# 1          1  Aug 29, 2023 @ 17:00:33.070  10.200.160.148           -
# 2          2  Aug 29, 2023 @ 17:00:33.072   180.248.46.18           -
# 3          3  Aug 29, 2023 @ 17:00:33.076     125.166.3.1           -
# 4          4  Aug 29, 2023 @ 17:00:59.118   103.108.23.13           -
# ...      ...                          ...             ...         ...
# 54475  54475   Sep 5, 2023 @ 00:26:40.840  202.80.216.211           -
# 54476  54476   Sep 5, 2023 @ 00:26:40.880    114.5.245.55           -
# 54477  54477   Sep 5, 2023 @ 00:26:40.907    114.5.245.55           -
# 54478  54478   Sep 5, 2023 @ 00:26:40.913     10.27.97.71           -
# 54479  54479   Sep 5, 2023 @ 00:26:42.985   10.23.147.226           -
#
#                 hostname                  time_local  \
# 0      vm-director-nginx  30/Aug/2023:00:00:02 +0700
# ...

# %%
df_X = df_dq.copy().drop(columns=['rule.mitre.tactic'])

# Show duplicated data
df_dq[df_X.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, timestamp, remote_addr, remote_user, hostname, time_local, request, status, body_bytes_sent, http_referer, http_user_agent, http_x_forwarded_for, time_iso8601, request_method, request_length, bytes_sent, http_referer2, request_time, upstream_connect_time, upstream_header_time, upstream_response_time, upstream_addr, upstream_status, connection, connection_requests, data.srcip, agent.ip, rule.mitre.tactic]
# Index: []
#
# [0 rows x 28 columns]
