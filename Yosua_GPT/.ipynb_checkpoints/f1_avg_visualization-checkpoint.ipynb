# %% [markdown]
# # F1 Macro-Averaged Metric Visualization
# In this notebook, we will explore the **F1 macro-averaged** metric, which is used for evaluating multi-class classification models. We'll explain how the F1 macro-average is calculated and visualize it in a clear, step-by-step approach.
#
# ## What is F1 Macro-Averaged?
# The **F1 score** is the harmonic mean of precision and recall. For multi-class classification, we can calculate the F1 score for each class and then average them. There are two main types of averaging:
#
# - **Macro-average**: Takes the F1 score for each class and computes the simple (unweighted) mean.
# - **Micro-average**: Combines the contributions of all classes before computing the F1 score.
#
# In this notebook, we focus on **macro-average**, which treats all classes equally.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %% [markdown]
# ## Step 1: Load a sample dataset
# We'll use the classic Iris dataset for this example. It contains 3 classes and 4 features.

# %%
# Load the Iris dataset
data = load_iris()
X = data.data
y = data.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Step 2: Train a Classification Model
# We'll train a simple **Random Forest Classifier** on the dataset.

# %%
# Train a Random Forest Classifier
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

# Predict the test set
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Step 3: Calculate F1-Macro-Averaged Score
# We'll calculate the F1 score for each class and compute the macro-average.

# %%
# Calculate F1 scores for each class
f1_per_class = f1_score(y_test, y_pred, average=None)
f1_macro_avg = f1_score(y_test, y_pred, average='macro')

# Display F1 scores for each class and the macro-average
print('F1 Scores for each class:', f1_per_class)
print('F1 Macro-Averaged Score:', f1_macro_avg)
# Out:
# F1 Scores for each class: [1. 1. 1.]
# F1 Macro-Averaged Score: 1.0

# %% [markdown]
# ## Step 4: Visualizing F1 Scores
# We will now plot the F1 scores for each class along with the macro-average to better understand the performance of the model across different classes.

# %%
# Create a bar plot for F1 scores of each class and macro-average
classes = data.target_names
plt.figure(figsize=(8, 6))
sns.barplot(x=classes, y=f1_per_class, palette='Blues')
plt.axhline(y=f1_macro_avg, color='r', linestyle='--', label=f'Macro Avg F1: {f1_macro_avg:.2f}')
plt.title('F1 Scores for Each Class and Macro-Average')
plt.ylabel('F1 Score')
plt.legend()
plt.show()
# Out:
# C:\Users\YOSUA N LATUPUTTY\AppData\Local\Temp\ipykernel_39660\2812451945.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=classes, y=f1_per_class, palette='Blues')

# %% [markdown]
# ## Step 5: In-depth Explanation of F1 Macro-Average
# 1. **F1 score** for each class is computed independently.
# 2. **Macro-average** is simply the mean of the individual F1 scores across all classes, treating each class equally regardless of its size or importance.
#
# ### Why use F1 Macro-Average?
# F1 macro-average is useful when you want to give equal importance to all classes, even if some classes are smaller or larger than others. It helps in assessing the model’s overall performance without biasing towards larger classes.

# %%
# Import confusion matrix visualization tool
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Calculate and display the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Use ConfusionMatrixDisplay for visualization
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=data.target_names)
disp.plot(cmap='Blues')

plt.title('Confusion Matrix')
plt.show()
